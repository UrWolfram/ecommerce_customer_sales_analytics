# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd


df = pd.read_csv(
    r"C:\Code\Python\DA_Projects\ecommerce_customer_sales_analytics\dataset\data.csv",
    encoding="latin1")

df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
print(df.dtypes) # Datentypen der Spalten herausfinden
# Out:
# InvoiceNo                 str
# StockCode                 str
# Description               str
# Quantity                int64
# InvoiceDate    datetime64[us]
# UnitPrice             float64
# CustomerID            float64
# Country                   str
# dtype: object
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Name: Quantity, Length: 541909, dtype: bool

# %%
# change date from string to numpy date
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"], format="%m/%d/%Y %H:%M")

print(df["InvoiceDate"].head())
print(type(df["InvoiceDate"].iloc[0]))
# Out:
# 0   2010-12-01 08:26:00
# 1   2010-12-01 08:26:00
# 2   2010-12-01 08:26:00
# 3   2010-12-01 08:26:00
# 4   2010-12-01 08:26:00
# Name: InvoiceDate, dtype: datetime64[us]
# <class 'pandas.Timestamp'>

# %% [markdown]
# ### how many empy fields?

# %%
df.isnull().mean() * 100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %% [markdown]
# Around 25% of all orders have no CustomerID and 0.26% have no desciption.

# %% [markdown]
# ### do we have duplicates rows in the df?

# %%
df.duplicated().sum()
# Out:
# np.int64(5268)

# %% [markdown]
# We have 5268 duplicated rows in the df.

# %% [markdown]
# ### what time window does the df has his data from?

# %%
print(df["InvoiceDate"].min())

print(df["InvoiceDate"].max())
# Out:
# 2010-12-01 08:26:00
# 2011-12-09 12:50:00

# %% [markdown]
# from 01.12.2010 to 09.12.2011

# %% [markdown]
# ### 6. how many customers do we have?

# %%
df["CustomerID"].nunique() # nunqiue() ignores NaN
# Out:
# 4372

# %% [markdown]
# we have 4372 unqiue Customers in the DataSet

# %% [markdown]
# ### 7. how many different products do we have?

# %%
df["StockCode"].nunique()
# Out:
# 4070

# %% [markdown]
# there are 4070 different products in the dataset

# %%
### 8. how many different countries does it get delivered to?
df["Country"].nunique()
# Out:
# 38

# %% [markdown]
# 38 different countries
